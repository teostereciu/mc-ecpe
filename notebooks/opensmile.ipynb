# %%
import opensmile

smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.emobase,
    feature_level=opensmile.FeatureLevel.Functionals,
)

testfp = '/Users/teodorastereciu/Documents/bachelors-project/mc-ecpe/data/interim/train_wav/dia1utt1.wav'

result_df = smile.process_file(testfp)
print(result_df.shape)
# Out:
# (1, 988)

# %%
len(smile.feature_names)
# Out:
# 988

# %%
result_df
# Out:
#                                                                                   pcm_intensity_sma_max  \
# file                                               start  end
# /Users/teodorastereciu/Documents/bachelors-proj... 0 days 0 days 00:00:06.380000           4.400937e-07
#
#                                                                                   pcm_intensity_sma_min  \
# file                                               start  end
# /Users/teodorastereciu/Documents/bachelors-proj... 0 days 0 days 00:00:06.380000           1.535803e-11
#
#                                                                                   pcm_intensity_sma_range  \
# file                                               start  end
# /Users/teodorastereciu/Documents/bachelors-proj... 0 days 0 days 00:00:06.380000             4.400783e-07
#
#                                                                                   pcm_intensity_sma_maxPos  \
# ...

# %%
copy_df = result_df

# %%
all_rows = [copy_df]*3
all_rows
# Out:
# [                                                                                  pcm_intensity_sma_max  \
#  file                                               start  end
#  /Users/teodorastereciu/Documents/bachelors-proj... 0 days 0 days 00:00:06.380000           4.400937e-07
#
#                                                                                    pcm_intensity_sma_min  \
#  file                                               start  end
#  /Users/teodorastereciu/Documents/bachelors-proj... 0 days 0 days 00:00:06.380000           1.535803e-11
#
#                                                                                    pcm_intensity_sma_range  \
#  file                                               start  end
#  /Users/teodorastereciu/Documents/bachelors-proj... 0 days 0 days 00:00:06.380000             4.400783e-07
#
#                                                                                    pcm_intensity_sma_maxPos  \
# ...

# %%
import pandas as pd 
audio_features_df = pd.concat(all_rows, axis=0)
audio_features_df.reset_index(drop=True, inplace=True)
audio_features_df
# Out:
#    F0semitoneFrom27.5Hz_sma3nz_amean  F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                          28.537718                                0.232244
# 1                          28.537718                                0.232244
# 2                          28.537718                                0.232244
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                    22.98646
# 1                                    22.98646
# 2                                    22.98646
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                   29.917765
# 1                                   29.917765
# 2                                   29.917765
#
#    F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                   34.273876
# 1                                   34.273876
# 2                                   34.273876
#
#    F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# ...

# %%
opensmile.FeatureSet.emobase
# Out:
# <FeatureSet.emobase: 'emobase/emobase'>

# %%
collapsed_series = copy_df.T.apply(lambda x: x.tolist())
#collapsed_df = collapsed_series.to_frame().T
collapsed_series
# Out:
# file                                       /Users/teodorastereciu/Documents/bachelors-project/mc-ecpe/data/interim/train_wav/dia1utt1.wav
# start                                                                                                                              0 days
# end                                                                                                                0 days 00:00:06.380000
# F0semitoneFrom27.5Hz_sma3nz_amean                                                   28.537718
# F0semitoneFrom27.5Hz_sma3nz_stddevNorm                                               0.232244
# F0semitoneFrom27.5Hz_sma3nz_percentile20.0                                          22.986460
# F0semitoneFrom27.5Hz_sma3nz_percentile50.0                                          29.917765
# F0semitoneFrom27.5Hz_sma3nz_percentile80.0                                          34.273876
# ...                                                                                       ...
# ...

# %%
# collapse columns so there is only one row

collapsed_df = copy_df.T.apply(lambda x: x.tolist(), axis=1)

new_df = collapsed_df.to_frame().T

new_df
# Out:
#                                        Loudness_sma3  \
# 0  [0.37777790427207947, 0.3769148290157318, 0.37...
#
#                                      alphaRatio_sma3  \
# 0  [-20.902299880981445, -21.932289123535156, -21...
#
#                                 hammarbergIndex_sma3  \
# 0  [34.09316635131836, 33.75372314453125, 32.5427...
#
#                                      slope0-500_sma3  \
# 0  [0.020515121519565582, 0.013901290483772755, 0...
#
#                                   slope500-1500_sma3  \
# 0  [-0.016511039808392525, -0.02157541550695896, ...
#
#                          F0semitoneFrom27.5Hz_sma3nz  \
# 0  [14.863547325134277, 13.471213340759277, 12.07...
#
#                                   jitterLocal_sma3nz  \
# 0  [0.0, 0.10193799436092377, 0.10193799436092377...
#
#                                shimmerLocaldB_sma3nz  \
# 0  [0.6668006777763367, 0.5679653882980347, 0.469...
#
#                                      HNRdBACF_sma3nz  \
# ...

# %%
new_df.to_csv('out.csv', index=False)

# %%
import pandas as pd
read = pd.read_csv('out.csv')  
read
# Out:
#                                        Loudness_sma3  \
# 0  [0.37777790427207947, 0.3769148290157318, 0.37...
#
#                                      alphaRatio_sma3  \
# 0  [-20.902299880981445, -21.932289123535156, -21...
#
#                                 hammarbergIndex_sma3  \
# 0  [34.09316635131836, 33.75372314453125, 32.5427...
#
#                                      slope0-500_sma3  \
# 0  [0.020515121519565582, 0.013901290483772755, 0...
#
#                                   slope500-1500_sma3  \
# 0  [-0.016511039808392525, -0.02157541550695896, ...
#
#                          F0semitoneFrom27.5Hz_sma3nz  \
# 0  [14.863547325134277, 13.471213340759277, 12.07...
#
#                                   jitterLocal_sma3nz  \
# 0  [0.0, 0.10193799436092377, 0.10193799436092377...
#
#                                shimmerLocaldB_sma3nz  \
# 0  [0.6668006777763367, 0.5679653882980347, 0.469...
#
#                                      HNRdBACF_sma3nz  \
# ...

# %%
ls = []
for i in range(0,3):
    ls += [read]

# %%
many_df = pd.concat(ls, axis=0)
many_df.reset_index(drop=True, inplace=True)
many_df
# Out:
#                                        Loudness_sma3  \
# 0  [0.37777790427207947, 0.3769148290157318, 0.37...
# 1  [0.37777790427207947, 0.3769148290157318, 0.37...
# 2  [0.37777790427207947, 0.3769148290157318, 0.37...
#
#                                      alphaRatio_sma3  \
# 0  [-20.902299880981445, -21.932289123535156, -21...
# 1  [-20.902299880981445, -21.932289123535156, -21...
# 2  [-20.902299880981445, -21.932289123535156, -21...
#
#                                 hammarbergIndex_sma3  \
# 0  [34.09316635131836, 33.75372314453125, 32.5427...
# 1  [34.09316635131836, 33.75372314453125, 32.5427...
# 2  [34.09316635131836, 33.75372314453125, 32.5427...
#
#                                      slope0-500_sma3  \
# 0  [0.020515121519565582, 0.013901290483772755, 0...
# 1  [0.020515121519565582, 0.013901290483772755, 0...
# 2  [0.020515121519565582, 0.013901290483772755, 0...
#
#                                   slope500-1500_sma3  \
# ...

# %%
data1 = {'col1': [1,2,3], 'col2': ['A','B','C']}
df1 = pd.DataFrame(data1)
concatenated_df = pd.concat([df1, many_df], axis=1)

concatenated_df
# Out:
#    col1 col2                                      Loudness_sma3  \
# 0     1    A  [0.37777790427207947, 0.3769148290157318, 0.37...
# 1     2    B  [0.37777790427207947, 0.3769148290157318, 0.37...
# 2     3    C  [0.37777790427207947, 0.3769148290157318, 0.37...
#
#                                      alphaRatio_sma3  \
# 0  [-20.902299880981445, -21.932289123535156, -21...
# 1  [-20.902299880981445, -21.932289123535156, -21...
# 2  [-20.902299880981445, -21.932289123535156, -21...
#
#                                 hammarbergIndex_sma3  \
# 0  [34.09316635131836, 33.75372314453125, 32.5427...
# 1  [34.09316635131836, 33.75372314453125, 32.5427...
# 2  [34.09316635131836, 33.75372314453125, 32.5427...
#
#                                      slope0-500_sma3  \
# 0  [0.020515121519565582, 0.013901290483772755, 0...
# 1  [0.020515121519565582, 0.013901290483772755, 0...
# 2  [0.020515121519565582, 0.013901290483772755, 0...
#
# ...

# %%
print('hi')
# Out:
# hi

# %%
import pandas as pd

df = pd.read_csv('/Users/teodorastereciu/Documents/bachelors-project/mc-ecpe/data/processed/processed_func_data.csv', dtype={'id':str})
df.head()
# Out:
#    filename  id                                  conversation_line   emotion  \
# 0  dia1utt1  00  Alright , so I am back in high school , I am s...   neutral
# 1  dia1utt2  01                       Oh , yeah . Had that dream .   neutral
# 2  dia1utt3  02  Then I look down , and I realize there is a ph...  surprise
# 3  dia1utt4  03                                   Instead of ... ?  surprise
# 4  dia1utt5  04                                    That is right .     anger
#
#     speaker  pcm_intensity_sma_max  pcm_intensity_sma_min  \
# 0  Chandler           4.400937e-07           1.535803e-11
# 1       All           2.221042e-07           8.684786e-11
# 2  Chandler           7.866203e-07           8.263280e-12
# 3      Joey           2.768903e-07           1.009953e-10
# 4  Chandler           7.087501e-07           8.615216e-10
#
#    pcm_intensity_sma_range  pcm_intensity_sma_maxPos  \
# 0             4.400783e-07                     394.0
# ...

# %%
import numpy as np

X_train_audio = np.array(df[df['split'] == 'train'].drop(columns=['filename', 'id', 'conversation_line', 'emotion', 'speaker', 'split']).values.tolist())
X_val_audio = np.array(df[df['split'] == 'val'].drop(columns=['filename', 'id', 'conversation_line', 'emotion', 'speaker', 'split']).values.tolist())
X_test_audio = np.array(df[df['split'] == 'test'].drop(columns=['filename', 'id', 'conversation_line', 'emotion', 'speaker', 'split']).values.tolist())

# %%
X_train_audio.shape
# Out:
# (9966, 988)

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
import tensorflow as tf

def encode_labels(text_labels):
    """ One-hot encodes emotion labels. """

    labels = ['neutral', 'joy', 'surprise', 'anger', 'fear', 'disgust', 'sadness']
    num_classes = len(labels)
    label_to_index = {label: index for index, label in enumerate(labels)}
    index_to_label = {index: label for index, label in enumerate(labels)}

    idx_labels = [label_to_index[label] for label in text_labels]
    onehot_labels = tf.one_hot(idx_labels, len(labels)).numpy()
    return onehot_labels

train_labels = df[df['split'] == 'train']['emotion']
val_labels = df[df['split'] == 'val']['emotion']
test_labels = df[df['split'] == 'test']['emotion']

y_train = encode_labels(train_labels)
y_val = encode_labels(val_labels)
y_test = encode_labels(test_labels)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel '.venv (Python 3.10.9)' due to a connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import tensorflow as tf


input_layer = tf.keras.layers.Input(shape=(988,))

x = tf.keras.layers.Dense(256, activation='relu')(input_layer)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(7, activation='softmax')(x)

model = tf.keras.Model(input_layer, outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:674, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap>:571, in module_from_spec(spec)
#
# File <frozen importlib._bootstrap_external>:1176, in create_module(self, spec)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# ImportError: dlopen(/Users/teodorastereciu/Documents/bachelors-project/mc-ecpe/.venv/lib/python3.10/site-packages/tensorflow/python/platform/_pywrap_cpu_feature_guard.so, 0x0002): Library not loaded: @rpath/libtensorflow_framework.2.dylib
# ...

# %%
X_train_audio = np.array(df.head(100).drop(columns=['filename', 'id', 'conversation_line', 'emotion', 'speaker']).to_list())

# %%
history = model.fit(X_train_audio, y_train, validation_data=(X_val_audio, y_val), epochs=3, batch_size=64)

# %%
import tensorflow as tf
import tensorflow_text
import tensorflow_hub as hub

text_input = tf.keras.layers.Input(shape=(), dtype=tf.string)
preprocessor = hub.KerasLayer(
    "https://kaggle.com/models/tensorflow/bert/TensorFlow2/en-uncased-preprocess/3")
encoder_inputs = preprocessor(text_input)
encoder = hub.KerasLayer(
    "https://www.kaggle.com/models/tensorflow/bert/TensorFlow2/en-uncased-l-24-h-1024-a-16/4",
    trainable=True)
outputs = encoder(encoder_inputs)
pooled_output = outputs["pooled_output"]      # [batch_size, 1024].
sequence_output = outputs["sequence_output"]  # [batch_size, seq_length, 1024].

embedding_model = tf.keras.Model(text_input, pooled_output)
sentences = tf.constant(["(your text here)"])
print(embedding_model(sentences))
